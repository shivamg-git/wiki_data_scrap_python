# %% [markdown]
# # Importing packages

# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %% [markdown]
# # Download and Load state_and_union_territories_of_India Page to beautifulSoup.

# %%
# url = "https://en.wikipedia.org/wiki/States_and_union_territories_of_India"
# content = urlopen(url).read()
# soup = BeautifulSoup(content)
# file = open("States_and_union_territories_of_India.html","w")
# file.write(soup.prettify())
# file.close()

# %% [markdown]
# # Scrapping the Links of state from page.

# %%
file = open("./States_and_union_territories_of_India.html","r")
content = file.read()
soup = BeautifulSoup(content)
tables = soup.findAll("table",{'class': "wikitable"})
table1 = tables[0].findAll("th",{'scope':"row"})
table2 = tables[1].findAll("th",{'scope':"row"})

state_list=[]
for t in table1:
    for a in t.findAll('a',href=True):
        state_list.append("https://en.wikipedia.org/"+a['href'])

for t in table2:
    for a in t.findAll('a',href=True):
        state_list.append("https://en.wikipedia.org/"+a['href'])

state_list
# Out:
# ['https://en.wikipedia.org//wiki/Andhra_Pradesh',
#  'https://en.wikipedia.org//wiki/Arunachal_Pradesh',
#  'https://en.wikipedia.org//wiki/Assam',
#  'https://en.wikipedia.org//wiki/Bihar',
#  'https://en.wikipedia.org//wiki/Chhattisgarh',
#  'https://en.wikipedia.org//wiki/Goa',
#  'https://en.wikipedia.org//wiki/Gujarat',
#  'https://en.wikipedia.org//wiki/Haryana',
#  'https://en.wikipedia.org//wiki/Himachal_Pradesh',
#  'https://en.wikipedia.org//wiki/Jammu_and_Kashmir',
#  'https://en.wikipedia.org//wiki/Jharkhand',
#  'https://en.wikipedia.org//wiki/Karnataka',
#  'https://en.wikipedia.org//wiki/Kerala',
#  'https://en.wikipedia.org//wiki/Madhya_Pradesh',
#  'https://en.wikipedia.org//wiki/Maharashtra',
#  'https://en.wikipedia.org//wiki/Manipur',
#  'https://en.wikipedia.org//wiki/Meghalaya',
#  'https://en.wikipedia.org//wiki/Mizoram',
#  'https://en.wikipedia.org//wiki/Nagaland',
#  'https://en.wikipedia.org//wiki/Odisha',
#  'https://en.wikipedia.org//wiki/Punjab,_India',
#  'https://en.wikipedia.org//wiki/Rajasthan',
#  'https://en.wikipedia.org//wiki/Sikkim',
#  'https://en.wikipedia.org//wiki/Tamil_Nadu',
#  'https://en.wikipedia.org//wiki/Telangana',
#  'https://en.wikipedia.org//wiki/Tripura',
#  'https://en.wikipedia.org//wiki/Uttar_Pradesh',
#  'https://en.wikipedia.org//wiki/Uttarakhand',
#  'https://en.wikipedia.org//wiki/West_Bengal',
#  'https://en.wikipedia.org//wiki/Andaman_and_Nicobar_Islands',
#  'https://en.wikipedia.org//wiki/Chandigarh',
#  'https://en.wikipedia.org//wiki/Dadra_and_Nagar_Haveli',
#  'https://en.wikipedia.org//wiki/Daman_and_Diu',
#  'https://en.wikipedia.org//wiki/Delhi',
#  'https://en.wikipedia.org//wiki/Lakshadweep',
#  'https://en.wikipedia.org//wiki/Puducherry']

# %% [markdown]
# # Download state pages

# %%
# states=[]
# for url in state_list:
#     state=[]
#     title = url.split("/")[-1]
#     state.append(title)
#     state.append(url)
#     content = urlopen(url).read()
#     soup = BeautifulSoup(content)
#     state.append(soup)
#     file = open(title+".html","w")
#     file.write(soup.prettify())
#     file.close
#     states.append(state)

# %% [markdown]
# # Loading Pages from Downloaded Page

# %%
states=[]
for url in state_list:
    state={}
    title = url.split("/")[-1]
    state['title']=title
    state['url']  =url
    file = open(title+".html",'r')
    content = file.read()
    soup = BeautifulSoup(content)
    state['content']=soup
    file.close()
    states.append(state)

# %% [markdown]
# # finding div that conten data in page

# %%
for state in states:
    religion_div = None
    mydivs = state['content'].findAll("div", {"class": "thumbcaption"})
    for div in mydivs:
        legend_div = div.findAll("div", {"class": "legend"})
        if(len(legend_div) !=0):
            pp = div.findAll("p")
            t = pp[0].text
            if("Religion" in t):
                religion_div = div
    state['religion_div']=religion_div

# %% [markdown]
# # Extracting Content from div

# %%
for state in states:
    if(state['religion_div']):
        religion_div=state['religion_div']
        rel_divs = religion_div.findAll("div", {"class": "legend"})
        rel_dict=[]
        for rel in rel_divs:
            rel_dict.append(rel.text)
        state['rel_dict'] = rel_dict

# %% [markdown]
# # making key value pair for data

# %%
rel_list=set()
for state in states:
    if(state['religion_div']):
        per={}
        for s in state['rel_dict']:
            x = s.split()
            x = [x[0].strip(),x[-1].strip()]
            if(x[0]=="Not" or x[0]=="No" or x[0]=="not"):
                x[0]="NONE"
            per[x[0]]=float(x[-1][1:-2])
            rel_list.add(x[0])
        state["data"]=per

# %% [markdown]
# # filling data into a table

# %%
data=[]
temp=[]
temp.append("")
for r in rel_list:
    temp.append(r)
data.append(temp)
data

for state in states:
    if(state['content']):
        temp=[]
        temp.append(state['title'])
        for r in rel_list:
            try:
                temp.append(state['per'][r])
            except:
                pass
            temp.append("")
        data.append(temp)
        
data
# Out:
# [['',
#   'Other',
#   'Tribal',
#   'Judaism',
#   'Christianity',
#   'Others',
#   'Atheist',
#   'Buddhism',
#   'Irreligion',
#   'Atheism',
#   'Sarnaism',
#   'NONE',
#   'Naga',
#   'Jainism',
#   'Tibetan',
#   'Donyi-Polo',
#   'Sikhism',
#   'Islam',
#   'Sanamahism',
#   'Hinduism',
#   'Heraka',
#   'Animism'],
#  ['Andhra_Pradesh',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Arunachal_Pradesh',
#   0.84,
#   '',
#   '',
#   '',
#   30.26,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   11.76,
#   '',
#   26.2,
#   '',
#   '',
#   1.9,
#   '',
#   '',
#   29.04,
#   '',
#   '',
#   ''],
#  ['Assam',
#   0.16,
#   '',
#   '',
#   '',
#   3.74,
#   '',
#   '',
#   '',
#   0.18,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.08,
#   '',
#   '',
#   '',
#   0.07,
#   '',
#   34.22,
#   '',
#   '',
#   61.47,
#   '',
#   '',
#   0.09,
#   ''],
#  ['Bihar',
#   0.31,
#   '',
#   '',
#   '',
#   0.12,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   16.87,
#   '',
#   '',
#   82.69,
#   '',
#   '',
#   ''],
#  ['Chhattisgarh',
#   '',
#   '',
#   '',
#   1.92,
#   '',
#   '',
#   '',
#   0.27,
#   '',
#   '',
#   '',
#   3.01,
#   '',
#   '',
#   '',
#   0.24,
#   '',
#   '',
#   '',
#   0.27,
#   '',
#   2.01,
#   '',
#   '',
#   93.25,
#   '',
#   '',
#   ''],
#  ['Goa',
#   0.2,
#   '',
#   '',
#   '',
#   25.1,
#   '',
#   '',
#   '',
#   0.08,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.08,
#   '',
#   '',
#   '',
#   0.1,
#   '',
#   8.33,
#   '',
#   '',
#   66.08,
#   '',
#   '',
#   ''],
#  ['Gujarat',
#   '',
#   '',
#   '',
#   0.52,
#   '',
#   0.03,
#   '',
#   '',
#   0.05,
#   '',
#   '',
#   '',
#   '',
#   0.1,
#   '',
#   '',
#   0.96,
#   '',
#   '',
#   '',
#   0.1,
#   '',
#   9.67,
#   '',
#   '',
#   88.57,
#   '',
#   '',
#   ''],
#  ['Haryana',
#   '',
#   '',
#   '',
#   0.2,
#   '',
#   0.18,
#   '',
#   '',
#   0.03,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.21,
#   '',
#   '',
#   '',
#   4.91,
#   '',
#   7.03,
#   '',
#   '',
#   87.46,
#   '',
#   '',
#   ''],
#  ['Himachal_Pradesh',
#   0.2,
#   '',
#   '',
#   '',
#   0.18,
#   '',
#   '',
#   '',
#   1.15,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.03,
#   '',
#   '',
#   '',
#   1.16,
#   '',
#   2.18,
#   '',
#   '',
#   95.17,
#   '',
#   '',
#   ''],
#  ['Jammu_and_Kashmir',
#   0.01,
#   '',
#   '',
#   '',
#   0.28,
#   '',
#   '',
#   0.001,
#   '',
#   0.89,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.01,
#   '',
#   '',
#   '',
#   1.87,
#   '',
#   68.31,
#   '',
#   '',
#   28.43,
#   '',
#   '',
#   ''],
#  ['Jharkhand',
#   '',
#   '',
#   '',
#   4.3,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   12.8,
#   '',
#   0.6,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   14.5,
#   '',
#   '',
#   67.8,
#   '',
#   '',
#   ''],
#  ['Karnataka',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Kerala',
#   0.01,
#   '',
#   '',
#   '',
#   18.38,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   26.56,
#   '',
#   '',
#   54.73,
#   '',
#   '',
#   ''],
#  ['Madhya_Pradesh',
#   0.83,
#   '',
#   '',
#   '',
#   0.29,
#   '',
#   '',
#   '',
#   0.3,
#   '',
#   '',
#   '',
#   '',
#   0.13,
#   '',
#   '',
#   0.78,
#   '',
#   '',
#   '',
#   0.2,
#   '',
#   6.57,
#   '',
#   '',
#   90.89,
#   '',
#   '',
#   ''],
#  ['Maharashtra',
#   0.5,
#   '',
#   '',
#   '',
#   1.0,
#   '',
#   '',
#   '',
#   5.8,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   1.2,
#   '',
#   '',
#   '',
#   0.2,
#   '',
#   11.5,
#   '',
#   '',
#   79.8,
#   '',
#   '',
#   ''],
#  ['Manipur',
#   '',
#   '',
#   0.07,
#   '',
#   41.29,
#   '',
#   '',
#   '',
#   0.25,
#   '',
#   '',
#   '',
#   '',
#   0.38,
#   '',
#   '',
#   0.06,
#   '',
#   '',
#   '',
#   0.05,
#   '',
#   8.4,
#   '',
#   7.78,
#   '',
#   41.39,
#   '',
#   0.23,
#   '',
#   ''],
#  ['Meghalaya',
#   '',
#   8.7,
#   '',
#   '',
#   74.59,
#   '',
#   0.35,
#   '',
#   '',
#   0.33,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.02,
#   '',
#   '',
#   '',
#   0.1,
#   '',
#   4.39,
#   '',
#   '',
#   11.52,
#   '',
#   '',
#   ''],
#  ['Mizoram',
#   0.16,
#   '',
#   '',
#   '',
#   87.16,
#   '',
#   '',
#   '',
#   8.51,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.03,
#   '',
#   '',
#   '',
#   0.03,
#   '',
#   1.35,
#   '',
#   '',
#   2.75,
#   '',
#   '',
#   ''],
#  ['Nagaland',
#   '',
#   '',
#   '',
#   88.1,
#   '',
#   '',
#   '',
#   0.34,
#   '',
#   '',
#   '',
#   '',
#   0.1,
#   '',
#   0.14,
#   '',
#   0.13,
#   '',
#   '',
#   '',
#   0.1,
#   '',
#   2.44,
#   '',
#   '',
#   8.74,
#   '',
#   '',
#   ''],
#  ['Odisha',
#   '',
#   '',
#   '',
#   2.76,
#   '',
#   '',
#   '',
#   0.03,
#   '',
#   '',
#   '',
#   1.14,
#   '',
#   '',
#   '',
#   0.02,
#   '',
#   '',
#   '',
#   1.05,
#   '',
#   2.17,
#   '',
#   '',
#   93.63,
#   '',
#   '',
#   ''],
#  ['Punjab,_India',
#   0.35,
#   '',
#   '',
#   '',
#   1.26,
#   '',
#   '',
#   '',
#   0.12,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.16,
#   '',
#   '',
#   '',
#   57.69,
#   '',
#   1.93,
#   '',
#   '',
#   38.49,
#   '',
#   '',
#   ''],
#  ['Rajasthan',
#   0.01,
#   '',
#   '',
#   '',
#   0.14,
#   '',
#   '',
#   '',
#   0.02,
#   '',
#   '',
#   '',
#   '',
#   0.1,
#   '',
#   '',
#   0.91,
#   '',
#   '',
#   '',
#   1.27,
#   '',
#   9.07,
#   '',
#   '',
#   88.49,
#   '',
#   '',
#   ''],
#  ['Sikkim',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Tamil_Nadu',
#   0.3,
#   '',
#   '',
#   '',
#   6.12,
#   '',
#   '',
#   '',
#   0.01,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.12,
#   '',
#   '',
#   '',
#   0.02,
#   '',
#   5.86,
#   '',
#   '',
#   87.58,
#   '',
#   '',
#   ''],
#  ['Telangana',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Tripura',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Uttar_Pradesh',
#   '',
#   '',
#   '',
#   0.18,
#   '',
#   0.3,
#   '',
#   '',
#   0.1,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.11,
#   '',
#   '',
#   '',
#   0.32,
#   '',
#   19.26,
#   '',
#   '',
#   79.73,
#   '',
#   '',
#   ''],
#  ['Uttarakhand',
#   '',
#   '',
#   '',
#   0.37,
#   '',
#   0.13,
#   '',
#   '',
#   0.15,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.09,
#   '',
#   '',
#   '',
#   2.34,
#   '',
#   13.95,
#   '',
#   '',
#   82.97,
#   '',
#   '',
#   ''],
#  ['West_Bengal',
#   1.03,
#   '',
#   '',
#   '',
#   0.72,
#   '',
#   '',
#   '',
#   0.31,
#   '',
#   0.25,
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.07,
#   '',
#   '',
#   '',
#   0.07,
#   '',
#   27.01,
#   '',
#   '',
#   70.54,
#   '',
#   '',
#   ''],
#  ['Andaman_and_Nicobar_Islands',
#   0.5,
#   '',
#   '',
#   '',
#   21.7,
#   '',
#   '',
#   '',
#   0.08,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.33,
#   '',
#   8.51,
#   '',
#   '',
#   69.44,
#   '',
#   '',
#   ''],
#  ['Chandigarh',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Dadra_and_Nagar_Haveli',
#   0.08,
#   '',
#   '',
#   '',
#   1.48,
#   '',
#   '',
#   0.001,
#   '',
#   0.18,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.34,
#   '',
#   '',
#   '',
#   0.06,
#   '',
#   3.75,
#   '',
#   '',
#   93.93,
#   '',
#   '',
#   ''],
#  ['Daman_and_Diu',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   ''],
#  ['Delhi',
#   0.09,
#   '',
#   '',
#   '',
#   0.87,
#   '',
#   '',
#   '',
#   0.11,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   0.99,
#   '',
#   '',
#   '',
#   3.4,
#   '',
#   12.86,
#   '',
#   '',
#   81.68,
#   '',
#   '',
#   ''],
#  ['Lakshadweep',
#   0.0,
#   '',
#   '',
#   '',
#   0.05,
#   '',
#   '',
#   '',
#   0.0,
#   '',
#   '',
#   0.0,
#   '',
#   '',
#   '',
#   '',
#   0.0,
#   '',
#   '',
#   '',
#   0.0,
#   '',
#   77.58,
#   '',
#   '',
#   22.11,
#   '',
#   '',
#   ''],
#  ['Puducherry',
#   '',
#   '',
#   '',
#   6.2,
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   6.0,
#   '',
#   '',
#   87.3,
#   '',
#   '',
#   '']]

# %% [markdown]
# # using panda

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)
df
# Out:
#                              0      1       2        3             4       5   \
# 0                                Other  Tribal  Judaism  Christianity  Others
# 1                Andhra_Pradesh
# 2             Arunachal_Pradesh   0.84                                  30.26
# 3                         Assam   0.16                                   3.74
# 4                         Bihar   0.31                                   0.12
# 5                  Chhattisgarh                                  1.92
# 6                           Goa    0.2                                   25.1
# 7                       Gujarat                                  0.52
# 8                       Haryana                                   0.2
# 9              Himachal_Pradesh    0.2                                   0.18
# 10            Jammu_and_Kashmir   0.01                                   0.28
# 11                    Jharkhand                                   4.3
# 12                    Karnataka
# 13                       Kerala   0.01                                  18.38
# 14               Madhya_Pradesh   0.83                                   0.29
# 15                  Maharashtra    0.5                                      1
# 16                      Manipur                    0.07                 41.29
# 17                    Meghalaya            8.7                          74.59
# 18                      Mizoram   0.16                                  87.16
# 19                     Nagaland                                  88.1
# 20                       Odisha                                  2.76
# 21                Punjab,_India   0.35                                   1.26
# 22                    Rajasthan   0.01                                   0.14
# 23                       Sikkim
# 24                   Tamil_Nadu    0.3                                   6.12
# 25                    Telangana
# 26                      Tripura
# 27                Uttar_Pradesh                                  0.18
# 28                  Uttarakhand                                  0.37
# 29                  West_Bengal   1.03                                   0.72
# 30  Andaman_and_Nicobar_Islands    0.5                                   21.7
# 31                   Chandigarh
# 32       Dadra_and_Nagar_Haveli   0.08                                   1.48
# 33                Daman_and_Diu
# 34                        Delhi   0.09                                   0.87
# 35                  Lakshadweep      0                                   0.05
# 36                   Puducherry                                   6.2
#
#          6         7           8        9   ...      22     23     24     25  \
# 0   Atheist  Buddhism  Irreligion  Atheism  ...    None   None   None   None
# 1                                           ...    None   None   None   None
# 2                                           ...                 29.04
# 3                                     0.18  ...   34.22                61.47
# 4                                           ...   82.69
# 5                            0.27           ...    2.01                93.25
# 6                                     0.08  ...    8.33                66.08
# 7      0.03                           0.05  ...           9.67
# 8      0.18                           0.03  ...    7.03                87.46
# 9                                     1.15  ...    2.18                95.17
# 10                          0.001           ...          68.31
# 11                                          ...           67.8
# 12                                          ...    None   None   None   None
# 13                                          ...   54.73
# 14                                     0.3  ...           6.57
# 15                                     5.8  ...    11.5                 79.8
# 16                                    0.25  ...            8.4          7.78
# 17               0.35                       ...           4.39
# 18                                    8.51  ...    1.35                 2.75
# 19                           0.34           ...           2.44
# 20                           0.03           ...    2.17                93.63
# 21                                    0.12  ...    1.93                38.49
# 22                                    0.02  ...           9.07
# 23                                          ...    None   None   None   None
# 24                                    0.01  ...    5.86                87.58
# 25                                          ...    None   None   None   None
# 26                                          ...    None   None   None   None
# 27      0.3                            0.1  ...   19.26                79.73
# 28     0.13                           0.15  ...   13.95                82.97
# 29                                    0.31  ...          27.01
# 30                                    0.08  ...                 69.44
# 31                                          ...    None   None   None   None
# 32                          0.001           ...           3.75
# 33                                          ...    None   None   None   None
# 34                                    0.11  ...   12.86                81.68
# 35                                       0  ...          77.58
# 36                                          ...                         None
#
#        26     27    28    29    30    31
# 0    None   None  None  None  None  None
# 1    None   None  None  None  None  None
# 2                 None  None  None  None
# 3                 0.09        None  None
# 4    None   None  None  None  None  None
# 5                       None  None  None
# 6                       None  None  None
# 7   88.57                     None  None
# 8                       None  None  None
# 9                       None  None  None
# 10  28.43                     None  None
# 11          None  None  None  None  None
# 12   None   None  None  None  None  None
# 13   None   None  None  None  None  None
# 14  90.89                     None  None
# 15                      None  None  None
# 16         41.39        0.23
# 17  11.52                     None  None
# 18                      None  None  None
# 19   8.74                     None  None
# 20                      None  None  None
# 21                      None  None  None
# 22  88.49                     None  None
# 23   None   None  None  None  None  None
# 24                      None  None  None
# 25   None   None  None  None  None  None
# 26   None   None  None  None  None  None
# 27                      None  None  None
# 28                      None  None  None
# 29  70.54                     None  None
# 30                None  None  None  None
# 31   None   None  None  None  None  None
# 32  93.93                     None  None
# 33   None   None  None  None  None  None
# 34                      None  None  None
# 35  22.11                     None  None
# 36   None   None  None  None  None  None
#
# [37 rows x 32 columns]

# %%
df.to_excel("religion_data.xlsx")
